# %%
from typing import TypedDict, Annotated, Optional
from langgraph.graph import StateGraph, END, add_messages
from langgraph.types import Command
from langgraph.prebuilt import ToolNode
from langgraph.checkpoint.memory import MemorySaver
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool, InjectedToolCallId
from langchain_core.messages import HumanMessage, ToolMessage
from dotenv import load_dotenv
from langsmith import traceable
import asyncio

load_dotenv()

memory = MemorySaver()


class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    result: int

# %%
@tool
async def operate(
    a: int,
    b: int,
    tool_call_id: Annotated[str, InjectedToolCallId],
) -> Command:
    """Perform operation on 2 numbers"""

    await asyncio.sleep(5)
    return Command(
        update={
            "messages": [
                ToolMessage(
                    f"Operation performed successfully", tool_call_id=tool_call_id
                )
            ],
            "result": a + b,
        }
    )

# %%
tools = [operate]

model = ChatOpenAI(model="gpt-4o-mini", temperature=0).bind_tools(tools=tools)

tool_node = ToolNode(tools=tools)


@traceable
async def model_node(state: AgentState) -> AgentState:
    result = await model.ainvoke(state["messages"])
    return {**state, "messages": [result]}


@traceable
async def tools_router(state: AgentState):
    last_message = state["messages"][-1]

    if hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0:
        return "tool_node"

    return END


graph_builder = StateGraph(AgentState)

graph_builder.add_node("model", model_node)
graph_builder.add_node("tool_node", tool_node)

graph_builder.set_entry_point("model")

graph_builder.add_conditional_edges("model", tools_router)
graph_builder.add_edge("tool_node", "model")

graph = graph_builder.compile(checkpointer=memory)


async for event in graph.astream_events(
    {
        "messages": [HumanMessage(content="Perform operation on 10 and 4")],
        "result": 0,
    },
    {"configurable": {"thread_id": 11}},
):
    print(event)

# await graph.ainvoke(
#     {
#         "messages": [HumanMessage(content="Perform operation on 2 and 4")],
#         "result": 0,
#     },
#     {"configurable": {"thread_id": 11}},
# )
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={})], 'result': 0}}, 'name': 'LangGraph', 'tags': [], 'run_id': '65cba7de-eebb-441a-b848-986235f65328', 'metadata': {'thread_id': 11}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c')], 'result': 0}}, 'name': 'model', 'tags': ['graph:step:6'], 'run_id': '0e648adf-485d-41d7-a26c-a30f4fd3b4b2', 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c')]]}}, 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'operate', 'args': '', 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '{"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}], tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'a', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': 'a', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'a', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '10', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': '10', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '10', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ',"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': ',"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ',"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'b', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': 'b', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'b', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': '":', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '4', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': '4', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '4', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '}', 'name': None}, 'type': None}]}, response_metadata={}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', invalid_tool_calls=[{'name': None, 'args': '}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a')}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), 'input': {'messages': [[HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c')]]}}, 'run_id': 'd1709eba-8c17-44a9-9823-6d25a8ea820a', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['bcaec447-7c95-49f3-a289-a3112db87e23']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': '5bff828e-1d9a-4c95-a31d-d5902e08e886', 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328', '0e648adf-485d-41d7-a26c-a30f4fd3b4b2']}
# {'event': 'on_chain_end', 'data': {'output': 'tool_node', 'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}}, 'run_id': '5bff828e-1d9a-4c95-a31d-d5902e08e886', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328', '0e648adf-485d-41d7-a26c-a30f4fd3b4b2']}
# {'event': 'on_chain_stream', 'run_id': '0e648adf-485d-41d7-a26c-a30f4fd3b4b2', 'name': 'model', 'tags': ['graph:step:6'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9'}, 'data': {'chunk': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}, 'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c')], 'result': 0}}, 'run_id': '0e648adf-485d-41d7-a26c-a30f4fd3b4b2', 'name': 'model', 'tags': ['graph:step:6'], 'metadata': {'thread_id': 11, 'langgraph_step': 6, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:038214a1-8d8a-7ebf-765a-8c2615b614f9', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chain_stream', 'run_id': '65cba7de-eebb-441a-b848-986235f65328', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 11}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}}, 'name': 'tool_node', 'tags': ['graph:step:7'], 'run_id': '1e6e263d-6b51-4cc2-82d8-36cfbd7e847f', 'metadata': {'thread_id': 11, 'langgraph_step': 7, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_tool_start', 'data': {'input': {'a': 10, 'b': 4}}, 'name': 'operate', 'tags': ['seq:step:1'], 'run_id': '71d6fe2b-aa43-4c8a-822e-d8c647c848a8', 'metadata': {'thread_id': 11, 'langgraph_step': 7, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a', 'checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328', '1e6e263d-6b51-4cc2-82d8-36cfbd7e847f']}
# {'event': 'on_tool_end', 'data': {'output': Command(update={'messages': [ToolMessage(content='Operation performed successfully', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')], 'result': 14}), 'input': {'a': 10, 'b': 4, 'tool_call_id': 'call_uTKUPa4WdXOntk84rvDDKMxD'}}, 'run_id': '71d6fe2b-aa43-4c8a-822e-d8c647c848a8', 'name': 'operate', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 7, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a', 'checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328', '1e6e263d-6b51-4cc2-82d8-36cfbd7e847f']}
# {'event': 'on_chain_stream', 'run_id': '1e6e263d-6b51-4cc2-82d8-36cfbd7e847f', 'name': 'tool_node', 'tags': ['graph:step:7'], 'metadata': {'thread_id': 11, 'langgraph_step': 7, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a'}, 'data': {'chunk': [Command(update={'messages': [ToolMessage(content='Operation performed successfully', name='operate', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')], 'result': 14})]}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chain_end', 'data': {'output': [Command(update={'messages': [ToolMessage(content='Operation performed successfully', name='operate', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')], 'result': 14})], 'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}])], 'result': 0}}, 'run_id': '1e6e263d-6b51-4cc2-82d8-36cfbd7e847f', 'name': 'tool_node', 'tags': ['graph:step:7'], 'metadata': {'thread_id': 11, 'langgraph_step': 7, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:44d02b00-fcce-e3e9-c795-452e86157f0a', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chain_stream', 'run_id': '65cba7de-eebb-441a-b848-986235f65328', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 11}, 'data': {'chunk': {'tool_node': {'messages': [ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')], 'result': 14}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')], 'result': 14}}, 'name': 'model', 'tags': ['graph:step:8'], 'run_id': 'c0ba42c6-489f-48ec-8c01-75a9e4467b52', 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')]]}}, 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' operation', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='10', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')}, 'run_id': 'e7368a51-2716-4486-b44d-5205837a71b3', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-mini', 'ls_model_type': 'chat', 'ls_temperature': 0.0, 'ls_method': 'traceable'}, 'parent_ids': ['2ac05ca4-7ffd-4330-a4ec-7bbc6fae8ed1']}
# ...
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD'), AIMessage(content='The operation on 10 and 4 has been performed successfully. If you would like to know the result or specify a particular operation, please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')], 'result': 14}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': '894ac36c-d5e6-4e6d-be3e-9a7c5f436bfa', 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328', 'c0ba42c6-489f-48ec-8c01-75a9e4467b52']}
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD'), AIMessage(content='The operation on 10 and 4 has been performed successfully. If you would like to know the result or specify a particular operation, please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')], 'result': 14}}, 'run_id': '894ac36c-d5e6-4e6d-be3e-9a7c5f436bfa', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328', 'c0ba42c6-489f-48ec-8c01-75a9e4467b52']}
# {'event': 'on_chain_stream', 'run_id': 'c0ba42c6-489f-48ec-8c01-75a9e4467b52', 'name': 'model', 'tags': ['graph:step:8'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a'}, 'data': {'chunk': {'messages': [AIMessage(content='The operation on 10 and 4 has been performed successfully. If you would like to know the result or specify a particular operation, please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')], 'result': 14}}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='The operation on 10 and 4 has been performed successfully. If you would like to know the result or specify a particular operation, please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')], 'result': 14}, 'input': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD')], 'result': 14}}, 'run_id': 'c0ba42c6-489f-48ec-8c01-75a9e4467b52', 'name': 'model', 'tags': ['graph:step:8'], 'metadata': {'thread_id': 11, 'langgraph_step': 8, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:b2cb8d55-414e-75d3-6e02-8ed10c3f879a', 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': ['65cba7de-eebb-441a-b848-986235f65328']}
# {'event': 'on_chain_stream', 'run_id': '65cba7de-eebb-441a-b848-986235f65328', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 11, 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='The operation on 10 and 4 has been performed successfully. If you would like to know the result or specify a particular operation, please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')], 'result': 14}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='Perform operation on 5 and 4', additional_kwargs={}, response_metadata={}, id='e03b0566-ebc2-4723-bf77-0a407235fd7b'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'function': {'arguments': '{"a":5,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e2d38e95-b2ea-4284-bd26-0f9d882bd3b4', tool_calls=[{'name': 'operate', 'args': {'a': 5, 'b': 4}, 'id': 'call_bd3B2g6gA4nOFQjvamGMORpo', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='306e7f21-6401-40a9-83d3-cf09aebfe57a', tool_call_id='call_bd3B2g6gA4nOFQjvamGMORpo'), AIMessage(content='The operation on 5 and 4 has been performed successfully. If you need the result or a specific operation (like addition, subtraction, etc.), please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--1a3bafe7-8e78-4fad-a441-e66f0ec8a341'), HumanMessage(content='Perform operation on 10 and 4', additional_kwargs={}, response_metadata={}, id='ad43625b-df06-4a9e-b271-7693a4246d5c'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'function': {'arguments': '{"a":10,"b":4}', 'name': 'operate'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--d1709eba-8c17-44a9-9823-6d25a8ea820a', tool_calls=[{'name': 'operate', 'args': {'a': 10, 'b': 4}, 'id': 'call_uTKUPa4WdXOntk84rvDDKMxD', 'type': 'tool_call'}]), ToolMessage(content='Operation performed successfully', name='operate', id='9324c1b6-4b0d-4f8f-87f7-3deab85392d4', tool_call_id='call_uTKUPa4WdXOntk84rvDDKMxD'), AIMessage(content='The operation on 10 and 4 has been performed successfully. If you would like to know the result or specify a particular operation, please let me know!', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'service_tier': 'default'}, id='run--e7368a51-2716-4486-b44d-5205837a71b3')], 'result': 14}}, 'run_id': '65cba7de-eebb-441a-b848-986235f65328', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 11, 'LANGSMITH_PROJECT': 'agent', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'dc808ba-dirty'}, 'parent_ids': []}
